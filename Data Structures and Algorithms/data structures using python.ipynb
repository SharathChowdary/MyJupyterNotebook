# %% [markdown]
# # Data Structures
# A data structure is a named location that can be used to store and organize data. And, an algorithm is a collection of steps to solve a particular problem. Learning data structures and algorithms allow us to write efficient and optimized computer programs

# %% [markdown]
# # Cheat Sheet
# https://www.bigocheatsheet.com/

# %%
#Breadth first search
#It is an uninformed search
#level by level search
#Queue is used
#Time complexity = b power d where b is branch factor (Artificial intelligence)
#Time complexity = (V+E) where V is no.of nodes and E is no.of edges (Data Structures)
#It is complete
#Shallowest node
#Optimal
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}
visited=[]
queue=[]
def BFS(visited,graph,queue,node):
    visited.append(node)
    queue.append(node)
    while queue:
        m=queue.pop(0)
        print(m,end=" ")
        for neighbour in graph[m]:
            if neighbour not in visited:
                visited.append(neighbour)
                queue.append(neighbour)
BFS(visited,graph,queue,'5')
# Out:
# 5 3 7 2 4 8

# %%
#Depth first search algorithm
#Uninform search
#Deepest search
#Incomplete
#Non optimal
#Time complexity = b power d where b is branch factor and d is depth(Artificial intelligence)
#Time complexity = (V+E) where V is no.of nodes and E is no.of edges (Data Structures)
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}
visited=[]
def DFS(visited,graph,node):
    if node not in visited:
        visited.append(node)
        print(node,end=" ")
        for neighbour in graph[node]:
            DFS(visited,graph,neighbour)
DFS(visited,graph,'5')
# Out:
# 5 3 2 4 8 7

# %%
#linear search

def linear_search(lst,target):
    for i in range(len(lst)):
        if lst[i]==target:
            return i
    else:
        return -1
lst=[int(i) for i in input("Enter the elements seperated by space:").split()]
target=int(input("Enter the element to be searched: "))
result=linear_search(lst,target)
if result==-1:
    print("Element was not found...")
else:
    print("Element was found at index",result)
# Out:
# Enter the elements seperated by space:45 253 25 62 4 62 3
# Enter the element to be searched: 62
# Element was found at index 3

# %%
#binary search

def binary_search(lst,target):
    left=0
    right=len(lst)-1
    while left<=right:
        middle=(left+right)//2
        if lst[middle]==target:
            return middle
        elif target>lst[middle]:
            left=middle+1
        else:
            right=middle-1
    else:
        return -1
lst=[int(i) for i in input("Enter the elements seperated by space:").split()]
target=int(input("Enter the element to be searched: "))
result=binary_search(lst,target)
if result==-1:
    print("Element was not found...")
else:
    print("Element was found at index",result)
# Out:
# Enter the elements seperated by space:5 12 25 36 41 46 57 58 69 71 75 79 84
# Enter the element to be searched: 36
# Element was found at index 3

# %%
#binary search using recursions

def binary_search(lst,target,first,last):
    if first<=last:
        middle=(first+last)//2
        if lst[middle]==target:
            return middle
        elif lst[middle]<target:
            return binary_search(lst,target,middle+1,last)
        else:
            return binary_search(lst,target,first,middle-1)
    return -1
lst=[int(i) for i in input("Enter the elements seperated by space:").split()]
target=int(input("Enter the element to be searched: "))
result=binary_search(lst,target,0,len(lst)-1)
if result==-1:
    print("Element was not found...")
else:
    print("Element was found at index",result)
# Out:
# Enter the elements seperated by space:5 12 25 36 41 46 57 58 69 71 75 79 84
# Enter the element to be searched: 36
# Element was found at index 3

# %%
#sorting in ascending and descending order
lst=[45,26,2,3,52,3,56,25]
def des_ord(lst):
    for i in range(len(lst)):
        for j in range(i):
            if lst[i] > lst[j]:
                lst[i], lst[j] = lst[j], lst[i]
    for i in range(len(lst)):
        print(lst[i], end=" ")
def asc_ord(lst):
    for i in range(len(lst)):
        for j in range(i):
            if lst[i] < lst[j]:
                lst[i], lst[j] = lst[j], lst[i]
    for i in range(len(lst)):
        print(lst[i], end=" ")
asc_ord(lst)
print()
des_ord(lst)
# Out:
# 2 3 3 25 26 45 52 56
# 56 52 45 26 25 3 3 2

# %%
#bubble sort
def bubble_sort(lst):
    swapped=False
    for i in range(len(lst)-1):
        for j in range(len(lst)-i-1):
            if lst[j]>lst[j+1]:
                lst[j],lst[j+1]=lst[j+1],lst[j]
                swapped=True
        if not swapped:
            break
    return lst
lst=[int(i) for i in input("Enter list elements seperated by space: ").split()]
print("Sorted list is :",bubble_sort(lst))
# Out:
# Enter list elements seperated by space: 45 66 26 45 6 2 65 23
# Sorted list is : [2, 6, 23, 26, 45, 45, 65, 66]

# %%
#selection sort
def selection_sort(lst):
    for i in range(len(lst)-1):
        mini=i
        for j in range(i+1,len(lst)):
            if lst[mini]>lst[j]:
                mini=j
        lst[mini],lst[i]=lst[i],lst[mini]
    return lst
lst=[int(i) for i in input("Enter list elements seperated by space: ").split()]
print("Sorted list is :",selection_sort(lst))
# Out:
# Enter list elements seperated by space: 45 26 52 03 5 4 85
# Sorted list is : [3, 4, 5, 26, 45, 52, 85]

# %%
#Insertion sort
def insertionsort(lst):
    for i in range(1,len(lst)):
        anchor=lst[i]
        j=i-1
        while j>=0 and anchor<lst[j]:
            lst[j+1]=lst[j]
            j-=1
        lst[j+1]=anchor
lst=[
    [45,26,87,3,21,65,87,39,60,74,56,26],
    [5,5,5,6,5],
    [],
    [56,2,4,6,24,23,54,-96,45,2,28,-45,63]
    ]
for i in lst:
    insertionsort(i)
    print(i)
# Out:
# [3, 21, 26, 26, 39, 45, 56, 60, 65, 74, 87, 87]
# [5, 5, 5, 5, 6]
# []
# [-96, -45, 2, 2, 4, 6, 23, 24, 28, 45, 54, 56, 63]

# %%
# implementation of quick sort in python using hoare partition scheme

def swap(a, b, arr):
    if a!=b:
        tmp = arr[a]
        arr[a] = arr[b]
        arr[b] = tmp

def quick_sort(elements, start, end):
    if start < end:
        pi = partition(elements, start, end)
        quick_sort(elements, start, pi-1)
        quick_sort(elements, pi+1, end)

def partition(elements, start, end):
    pivot_index = start
    pivot = elements[pivot_index]

    while start < end:
        while start < len(elements) and elements[start] <= pivot:
            start+=1

        while elements[end] > pivot:
            end-=1

        if start < end:
            swap(start, end, elements)

    swap(pivot_index, end, elements)

    return end

elements=[45,32,15,65,78,3,98,69,42,57,7,31,18,25,89]
quick_sort(elements,0,len(elements)-1)
print(elements)
# Out:
# [3, 7, 15, 18, 25, 31, 32, 42, 45, 57, 65, 69, 78, 89, 98]

# %%
#lomuto partition (my code)
elements=[45,32,15,65,78,3,98,69,42,57,7,31,18,25,89]
def partition(start,end,lst):
    pivot_index=start
    i=start
    pivot=lst[end]
    while i<end:
        while pivot_index<end and lst[pivot_index]<=pivot:
            pivot_index+=1
        i=pivot_index
        while i<end and lst[i]>pivot:
            i+=1
        if pivot_index<end:
            lst[pivot_index],lst[i]=lst[i],lst[pivot_index]
    return pivot_index
def quicksort(start,end,lst):
    if start<end:
        pivot=partition(start,end,lst)
        quicksort(start,pivot-1,lst)
        quicksort(pivot+1,end,lst)
quicksort(0,len(elements)-1,elements)
print(elements)
# Out:
# [3, 7, 15, 18, 25, 31, 32, 42, 45, 57, 65, 69, 78, 89, 98]

# %%
#lamuto partition (from code basics)
elements=[45,32,15,65,78,3,98,69,42,57,7,31,18,25,89]
def swap(a, b, arr):
    if a!=b:
        tmp = arr[a]
        arr[a] = arr[b]
        arr[b] = tmp

def quick_sort(elements, start, end):
    if len(elements)== 1:
        return
    if start < end:
        pi = partition(elements, start, end)
        quick_sort(elements, start, pi-1)
        quick_sort(elements, pi+1, end)

def partition(elements, start, end):
    pivot = elements[end]
    p_index = start

    for i in range(start, end):
        if elements[i] <= pivot:
            swap(i, p_index, elements)
            p_index += 1

    swap(p_index, end, elements)

    return p_index
quick_sort(elements,0,len(elements)-1)
print(elements)
# Out:
# [3, 7, 15, 18, 25, 31, 32, 42, 45, 57, 65, 69, 78, 89, 98]

# %%
#simple quicksort implementation
lst=[45,25,3,63,0,54,6,2,63,87,23,6,5,87,99,52,56]
def QuickSort(lst):
    if len(lst)<=1:
        return lst
    pivot=lst[len(lst)//2]
    left=[x for x in lst if x<pivot]
    middle=[x for x in lst if x==pivot]
    right=[x for x in lst if x>pivot]
    return QuickSort(left)+middle+QuickSort(right)

QuickSort(lst)
# Out:
# [0, 2, 3, 5, 6, 6, 23, 25, 45, 52, 54, 56, 63, 63, 87, 87, 99]

# %%
#merge sort 

def merge_sort(arr):
    if len(arr) <= 1:
        return

    mid = len(arr)//2

    left = arr[:mid]
    right = arr[mid:]

    merge_sort(left)
    merge_sort(right)

    merge_two_sorted_lists(left, right, arr)

def merge_two_sorted_lists(a,b,arr):
    len_a = len(a)
    len_b = len(b)

    i = j = k = 0

    while i < len_a and j < len_b:
        if a[i] <= b[j]:
            arr[k] = a[i]
            i+=1
        else:
            arr[k] = b[j]
            j+=1
        k+=1

    while i < len_a:
        arr[k] = a[i]
        i+=1
        k+=1

    while j < len_b:
        arr[k] = b[j]
        j+=1
        k+=1

elements=[45,25,3,63,0,54,6,2,63,87,23,6,5,87,99,52,56]
merge_sort(elements)
print(elements)
# Out:
# [0, 2, 3, 5, 6, 6, 23, 25, 45, 52, 54, 56, 63, 63, 87, 87, 99]

# %%
#shell sort (my code)
def shellsort(lst):
    n=len(lst)
    gap=n//2
    while gap>=1:
        i=gap
        j=i-gap
        while i<n:
            if lst[i]<lst[j]:
                lst[i],lst[j]=lst[j],lst[i]
                while (j-gap)>=0 and lst[j]<lst[j-gap]:
                    lst[j],lst[j-gap]=lst[j-gap],lst[j]
                    j-=gap
            i+=1
            j+=1
        gap=gap//2
    return lst
elements=[
    [23,7,9,19,31,29,15,5,2],
    [],
    [1,2,3,4,5,6],
    [6,5,4,3,2,1],
    [5],
    [54,32,58,34,69,32,16,32,69,98,89,71]
]
for element in elements:
    print(shellsort(element))
# Out:
# [2, 5, 7, 9, 15, 19, 23, 29, 31]
# []
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [5]
# [16, 32, 32, 32, 34, 54, 58, 69, 69, 71, 89, 98]

# %%
#shell sort (from code basics)
def shell_sort(arr):
    size = len(arr)
    gap = size//2

    while gap > 0:
        for i in range(gap,size):
            anchor = arr[i]
            j = i
            while j>=gap and arr[j-gap]>anchor:
                arr[j] = arr[j-gap]
                j -= gap
            arr[j] = anchor
        gap = gap // 2
    return arr
elements=[
    [23,7,9,19,31,29,15,5,2],
    [],
    [1,2,3,4,5,6],
    [6,5,4,3,2,1],
    [5],
    [54,32,58,34,69,32,16,32,69,98,89,71]
]
for element in elements:
    print(shell_sort(element))
# Out:
# [2, 5, 7, 9, 15, 19, 23, 29, 31]
# []
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [5]
# [16, 32, 32, 32, 34, 54, 58, 69, 69, 71, 89, 98]

# %%
#Heap sort (my code)

#leaf nodes start from (n//2 + 1) to n if indexed from 1 to n
#leaf nodes start from (n//2) to (n-1) if indexed from 0 to n-1
#left node for parent node is (i+1)*2 and right node is (i+1)*2 + 1 if indexed from 1 to n
#left node for parent node is (i+1)*2 - 1 and right node is (i+1)*2 if indexed from 0 to n-1
element=[15,5,20,1,17,10,30]
def Heapify(lst):
    n=len(lst)
    for i in range((n//2)-1,-1,-1):
        left=(i+1)*2 -1
        right=(i+1)*2
        if right<n:
            maxi= left if lst[left] > lst[right] else right
        else:
            maxi=left
        if lst[i]<lst[maxi]:
            lst[i],lst[maxi]=lst[maxi],lst[i]
    for i in range(n//2):
        left=(i+1)*2 -1
        right=(i+1)*2
        if right<n:
            maxi= left if lst[left] > lst[right] else right
        else:
            maxi=left
        if lst[i]<lst[maxi]:
            lst[i],lst[maxi]=lst[maxi],lst[i]
    return lst
def HeapSort(lst):
    n=len(lst)
    result=[]
    for i in range(n):
        lst=Heapify(lst)
        result.insert(0,lst.pop(0))
    return result

elements=[
    [23,7,9,19,31,29,15,5,2],
    [],
    [1,2,3,4,5,6],
    [6,5,4,3,2,1],
    [5],
    [54,32,58,34,69,32,16,32,69,98,89,71]
]
for element in elements:
    print(HeapSort(element))
# Out:
# [2, 5, 7, 9, 15, 19, 23, 29, 31]
# []
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [5]
# [16, 32, 32, 32, 34, 54, 58, 69, 69, 71, 89, 98]

# %%
#Heap sort (from GeeksforGeeks)

def heapify(arr, n, i):
    largest = i  # Initialize largest as root
    l = 2 * i + 1  # left = 2*i + 1
    r = 2 * i + 2  # right = 2*i + 2
  
 # See if left child of root exists and is
 # greater than root
  
    if l < n and arr[i] < arr[l]:
        largest = l
  
 # See if right child of root exists and is
 # greater than root
  
    if r < n and arr[largest] < arr[r]:
        largest = r
  
 # Change root, if needed
  
    if largest != i:
        (arr[i], arr[largest]) = (arr[largest], arr[i])  # swap
  
  # Heapify the root.
  
        heapify(arr, n, largest)
  
  
# The main function to sort an array of given size
  
def heapSort(arr):
    n = len(arr)
  
 # Build a maxheap.
 # Since last parent will be at ((n//2)-1) we can start at that location.
  
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
  
 # One by one extract elements
  
    for i in range(n - 1, 0, -1):
        (arr[i], arr[0]) = (arr[0], arr[i])  # swap
        heapify(arr, i, 0)
  
  
# Driver code to test above
  
arr = [12, 11, 13, 5, 6, 7, ]
heapSort(arr)
n = len(arr)
print('Sorted array is')
for i in range(n):
    print(arr[i])

# %%
#counting sort
#it will not work with negative values
#negative values are to be normalised in order to work with negative values
#i.e [3,-5,6,-2,7,8]-->[8,0,11,3,12,13] (every element is added with +5 since -5 is least negative value)


"""
#normalised code that can handle negative values


elements=[2,1,1,0,2,5,4,0,-5,-8,2,8,7,7,9,2,0,1,9]
def countingsort(lst):
    n=len(lst)
    mini=min(lst)
    normalised=False
    if mini<0:
        lst=[x+abs(mini) for x in lst]
        normalised=True
    k=max(lst)
    count=[0 for x in range(k+1)]
    result=[0 for x in range(n)]
    for element in lst:
        count[element]+=1
    for i in range(1,k+1):
        count[i]=count[i]+count[i-1]
    for i in range(n-1,-1,-1):
        count[lst[i]]-=1
        result[count[lst[i]]]=lst[i]
    for i in range(n):
        lst[i]=result[i]
    return [x+mini for x in lst] if normalised else lst
print(countingsort(elements))
"""


elements=[2,1,1,0,2,5,4,0,2,8,7,7,9,2,0,1,9]
def CountingSort(lst):
    k=max(lst)
    n=len(lst)
    count=[0 for i in range(k+1)]
    for i in range(n):
        count[lst[i]]+=1
    for i in range(1,k+1):
        count[i]=count[i]+count[i-1]
    temp=[0 for i in range(n)]
    for i in range(n-1,-1,-1):#iterating from last to maintain stability
        count[lst[i]]-=1
        temp[count[lst[i]]]=lst[i]
    #copying temp array to original array
    for i in range(n):
        lst[i]=temp[i]
    return lst
CountingSort(elements)
# Out:
# [0, 0, 0, 1, 1, 1, 2, 2, 2, 2, 4, 5, 7, 7, 8, 9, 9]

# %%
#sorting a string using counting sort
string="artificial intelligence"
def CountingSort(string):
    n=len(string)
    count=[0 for x in range(256)]
    for i in range(n):
        count[ord(string[i])]+=1
    for i in range(1,256):
        count[i]=count[i]+count[i-1]
    temp=[0 for x in range(n)]
    for i in range(n-1,-1,-1):
        count[ord(string[i])]-=1
        temp[count[ord(string[i])]]=string[i]
    sort_str=""
    for char in temp:
        sort_str+=char
    return sort_str
CountingSort(string)
# Out:
# ' aacceeefgiiiiilllnnrtt'

# %% [markdown]
# # Linked Lists

# %% [markdown]
# ![Screenshot%20%28404%29.png](attachment:Screenshot%20%28404%29.png)

# %%
#Singly Linked list basic problem
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
    def show(self):
        temp=self.head
        while(temp):
            print(temp.data)
            temp=temp.next
lst=LinkedList()
lst.head=Node(1)
second=Node(2)
third=Node(3)
fourth=Node(4)
lst.head.next=second
second.next=third
third.next=fourth
lst.show()
# Out:
# 1
# 2
# 3
# 4

# %%
#Singly Linked list

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
    def show(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" ")
            temp=temp.next
    def insert_at_beginning(self,data):
        newnode=Node(data)
        newnode.next=self.head
        self.head=newnode
    def insert_at_end(self,data):
         if self.head==None:
             self.insert_at_beginning(data)
         else:
            temp=self.head
            while(temp.next):
                temp=temp.next
            temp.next=Node(data)
    def get_length(self):
        count=0
        temp=self.head
        while(temp):
            count+=1
            temp=temp.next
        return count
    def insert_at_position(self,pos,data):
        if pos<0 or pos>=self.get_length():
            raise Exception("Invalid index")
        elif pos==0:
            self.insert_at_beginning(data)
        else:
            count=0
            temp=self.head
            while(temp):
                if count==pos:
                    newnode=Node(data)
                    newnode.next=temp.next
                    temp.next=newnode
                count+=1
                temp=temp.next
     """ (or)
        def insert_at_position(self,pos,value):
            if pos<0:
                print("cannot insert at position",pos)
            elif pos==0:
                lst.insert_at_beginning(value)
            else:
                count=0
                temp=self.head
                while(temp):
                    if count==pos-1:
                        newnode=Node(value)
                        newnode.next=temp.next
                        temp.next=newnode
                    temp=temp.next
                    count+=1
        """
    def insert_multiple_values(self,values):
        for value in values:
            self.insert_at_end(value)
    def remove_at_beginning(self):
        if self.head==None:
            print("LinkedList is empty")
            return
        temp=self.head
        self.head=self.head.next
        temp=None
    def remove_at_end(self):
        if self.head==Node:
            print("LinkedList is empty")
            return
        temp=self.head
        while(temp.next.next):
            temp=temp.next
        temp.next=None
    def remove_at_position(self,pos):
        if pos<0 or pos>=self.get_length():
            raise Exception("Invalid index")
        elif pos==0:
            self.remove_at_beginning()
        else:
            temp=self.head
            count=0
            while(temp.next):
                if count==pos-1:
                    temp.next=temp.next.next
                count+=1
                temp=temp.next


lst=LinkedList()
lst.insert_at_beginning(1)
lst.show()
print()
lst.insert_at_beginning(2)
lst.show()
print()
lst.insert_at_end(3)
lst.show()
print()
lst.insert_at_end(4)
lst.show()
print()
lst.insert_at_position(3,"three")
lst.show()
print()
lst.insert_at_position(2,"four")
lst.show()
print()
lst.insert_multiple_values([10,20,30,40,50,60])
lst.show()
print()
lst.remove_at_beginning()
lst.show()
print()
lst.remove_at_end()
lst.show()
print()
lst.remove_at_position(2)
lst.show()
print()
lst.remove_at_position(3)
lst.show()
print()
# Out:
# 1
# 2 1
# 2 1 3
# 2 1 3 4
# 2 1 3 4 three
# 2 1 3 four 4 three
# 2 1 3 four 4 three 10 20 30 40 50 60
# 1 3 four 4 three 10 20 30 40 50 60
# 1 3 four 4 three 10 20 30 40 50
# 1 3 4 three 10 20 30 40 50
# 1 3 4 10 20 30 40 50

# %%
#singly linked list
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class LinkedList:
    def __init__(self):
        self.head=None
    def insert_at_beginning(self,value):
        newnode=Node(value)
        newnode.next=self.head
        self.head=newnode
    def insert_at_end(self,value):
        temp=self.head
        while(temp.next):
            temp=temp.next
        temp.next=Node(value)
    def insert_at_position(self,pos,value):
        if pos<0:
            print("cannot insert at position",pos)
        elif pos==0:
            lst.insert_at_beginning(value)
        else:
            i=0
            temp=self.head
            while(i<pos-1):
                temp=temp.next
                i+=1
            newnode=Node(value)
            newnode.next=temp.next
            temp.next=newnode
        """ (or)
        def insert_at_position(self,pos,value):
            if pos<0:
                print("cannot insert at position",pos)
            elif pos==0:
                lst.insert_at_beginning(value)
            else:
                count=0
                temp=self.head
                while(temp):
                    if count==pos-1:
                        newnode=Node(value)
                        newnode.next=temp.next
                        temp.next=newnode
                    temp=temp.next
                    count+=1
        """
    def insert_multiple_elements(self,values):
        for value in values:
            self.insert_at_end(value)
    def remove_at_beginning(self):
        if self.head!=None:
            temp=self.head
            self.head=self.head.next
            temp=None
    def remove_at_end(self):
        temp=self.head
        while(temp.next.next):
            temp=temp.next
        temp.next=None
    def get_length(self):
        count=0
        temp=self.head
        while(temp):
            temp=temp.next
            count+=1
        return count
    def remove_at_position(self,pos):
        if pos < 0 or pos>=self.get_length():
            raise Exception("Invalid index")
        elif pos==0:
            self.remove_at_beginning()
        else:
            count=0
            temp=self.head
            while(temp):
                if count==pos-1:
                    temp.next=temp.next.next
                temp=temp.next
                count+=1
    def show(self):
        temp=self.head
        while(temp):
            print(temp.data)
            temp=temp.next
lst=LinkedList()
lst.insert_at_beginning(1)
lst.insert_at_beginning(2)
lst.insert_at_beginning(3)
lst.insert_at_beginning(4)
lst.insert_at_end(5)
lst.insert_at_end(6)
lst.insert_at_position(3,"three")
lst.remove_at_end()
lst.remove_at_position(0)
lst.remove_at_position(3)
lst.insert_multiple_elements([10,20,30,40,50])
lst.show()
print("Length:",lst.get_length())
# Out:
# 3
# 2
# three
# 5
# 10
# 20
# 30
# 40
# 50
# Length: 9

# %%
#Doubly linked list basic code

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class LinkedList:
    def __init__(self):
        self.head=None
        self.tail=None
    def forward_printing(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.next
    def reverse_printing(self):
        temp=self.tail
        while(temp): 
            print(temp.data,end=" --> ")
            temp=temp.prev
lst=LinkedList()
lst.head=Node(1)
second=Node(2)
third=Node(3)
fourth=Node(4)
lst.head.next=second
second.next=third
third.next=fourth
lst.tail=fourth
fourth.prev=third
third.prev=second
second.prev=lst.head
lst.forward_printing()
print()
lst.reverse_printing()
# Out:
# 1 --> 2 --> 3 --> 4 -->
# 4 --> 3 --> 2 --> 1 -->

# %%
#Doubly linked list

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class LinkedList:
    def __init__(self):
        self.head=None
        self.tail=None
    def forward_printing(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.next
        print()
    def reverse_printing(self):
        temp=self.tail
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.prev
        print()
    def insert_at_beginning(self,data):
        if self.head==None:
            self.head=self.tail=Node(data)
            self.head.prev=None
            self.head.next=None
            return
        temp=self.head
        newnode=Node(data)
        newnode.next=temp
        temp.prev=newnode
        newnode.prev=None
        self.head=newnode
    def insert_at_end(self,data):
        if self.head==None:
            self.head=self.tail=Node(data)
            self.head.prev=None
            self.head.next=None
            return
        newnode=Node(data)
        temp=self.tail
        temp.next=newnode
        newnode.prev=temp
        newnode.next=None
        self.tail=newnode
    def length(self):
        temp=self.head
        count=0
        while(temp):
            temp=temp.next
            count+=1
        return count
    def insert_at_position(self,pos,data):
        if pos<0 or pos>=self.length():
            print("Invalid index")
            return
        count=0
        temp=self.head
        newnode=Node(data)
        while(temp):
            if count==pos-1:
                newnode.next=temp.next
                temp.next.prev=newnode
                newnode.prev=temp
                temp.next=newnode
            temp=temp.next
            count+=1
    def remove_at_beginning(self):
        if self.length()==0:
            print("Linked list is already empty")
            return
        temp=self.head
        self.head=self.head.next
        self.head.prev=None
        temp=None
    def remove_at_end(self):
        if self.length()==0:
            print("Linked list is already empty")
            return
        temp=self.tail
        self.tail=self.tail.prev
        self.tail.next=None
        temp=None
    def remove_at_position(self,pos):
        if pos<0 or pos >= self.length():
            print("Invalid index")
            return
        if pos==0:
            self.remove_at_beginning()
            return
        if pos == self.length()-1:
            self.remove_at_end()
            return
        count=0
        temp=self.head
        while(temp):
            if count==pos-1:
                temp1=temp.next
                temp.next=temp1.next
                temp.next.prev=temp
                temp1=None
            count+=1
            temp=temp.next
    def insert_multiple_elements(self,values):
            for value in values:
                self.insert_at_end(value)
    def index(self,value):
        temp=self.head
        count=0
        while(temp):
            if temp.data==value:
                return count
            temp=temp.next
            count+=1
    def count(self,value):
            count=0
            temp=self.head
            while(temp):
                if temp.data==value:
                    count+=1
                temp=temp.next
            return count
                
                
        
lst=LinkedList()
lst.insert_at_beginning(1)
lst.insert_at_beginning(2)
lst.insert_at_beginning(3)
lst.forward_printing()
lst.reverse_printing()
lst.insert_at_end(4)
lst.insert_at_end(5)
lst.forward_printing()
lst.reverse_printing()
lst.insert_at_position(3,"three")
lst.insert_at_position(1,"one")
lst.insert_at_position(5,1)
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_beginning()
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_end()
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_position(3)
lst.forward_printing()
lst.reverse_printing()
lst.insert_multiple_elements([10,20,30,40,50])
lst.forward_printing()
lst.reverse_printing()
print("Length:",lst.length())
print("index of element:",lst.index(4))
print("number of occurances of an element",lst.count(1))
# Out:
# 3 --> 2 --> 1 -->
# 1 --> 2 --> 3 -->
# 3 --> 2 --> 1 --> 4 --> 5 -->
# 5 --> 4 --> 1 --> 2 --> 3 -->
# 3 --> one --> 2 --> 1 --> three --> 1 --> 4 --> 5 -->
# 5 --> 4 --> 1 --> three --> 1 --> 2 --> one --> 3 -->
# one --> 2 --> 1 --> three --> 1 --> 4 --> 5 -->
# 5 --> 4 --> 1 --> three --> 1 --> 2 --> one -->
# one --> 2 --> 1 --> three --> 1 --> 4 -->
# 4 --> 1 --> three --> 1 --> 2 --> one -->
# one --> 2 --> 1 --> 1 --> 4 -->
# 4 --> 1 --> 1 --> 2 --> one -->
# one --> 2 --> 1 --> 1 --> 4 --> 10 --> 20 --> 30 --> 40 --> 50 -->
# 50 --> 40 --> 30 --> 20 --> 10 --> 4 --> 1 --> 1 --> 2 --> one -->
# Length: 10
# index of element: 4
# number of occurances of an element 2

# %%
#Circlular linked list basic code

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class LinkedList:
    def __init__(self):
        self.head=None
        self.tail=None
    def forward_printing(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.next
            if temp==self.head:
                break
        print()
    def reverse_printing(self):
        temp=self.tail
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.prev
            if temp==self.tail:
                break
        print()
lst=LinkedList()
lst.head=Node(1)
second=Node(2)
third=Node(3)
fourth=Node(4)
lst.head.next=second
second.next=third
third.next=fourth
lst.tail=fourth
fourth.prev=third
third.prev=second
second.prev=lst.head
lst.head.prev=lst.tail
fourth.next=lst.head
lst.forward_printing()
print()
lst.reverse_printing()
# Out:
# 1 --> 2 --> 3 --> 4 -->
#
# 4 --> 3 --> 2 --> 1 -->

# %%
#circular LInked list

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
class LinkedList:
    def __init__(self):
        self.head=None
        self.tail=None
    def forward_printing(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.next
            if temp==self.head:
                break
        print()
    def reverse_printing(self):
        temp=self.tail
        while(temp):
            print(temp.data,end=" --> ")
            temp=temp.prev
            if temp==self.tail:
                break
        print()
    def insert_at_beginning(self,data):
        if self.head==None:
            self.head=self.tail=Node(data)
        else:
            newnode=Node(data)
            newnode.next=self.head
            self.head.prev=newnode
            newnode.prev=self.tail
            self.head=newnode
            self.tail.next=self.head
    def insert_at_end(self,data):
        if self.head==None:
            self.head=self.tail=Node(data)
            return
        newnode=Node(data)
        self.tail.next=newnode
        newnode.prev=self.tail
        self.tail=newnode
        self.tail.next=self.head
        self.head.prev=self.tail
    def length(self): 
        temp=self.head
        count=0
        while(temp):
            count+=1
            temp=temp.next
            if temp==self.head:
                break
        return count
    def insert_at_position(self,pos,data):
        if pos<0 or pos>=self.length():
            raise Exception("Invalid index")
            return
        if pos==0:
            self.insert_at_beginning(data)
            return
        count=0
        temp=self.head
        while(temp):
            if count==pos-1:
                newnode=Node(data)
                newnode.next=temp.next
                newnode.prev=temp
                temp.next.prev=newnode
                temp.next=newnode
            temp=temp.next
            count+=1
            if temp==self.head:
                break
    def insert_multiple_values(self,values):
        for value in values:
            self.insert_at_end(value)
    def remove_at_beginning(self):
        if self.head==None:
            print("Linked list is already empty")
            return
        temp=self.head
        self.head=self.head.next
        temp=None
        self.tail.next=self.head
        self.head.prev=self.tail
    def remove_at_end(self):
        if self.head==None:
            print("Linked list is already empty")
            return
        temp=self.tail.prev
        temp.next=self.head
        self.tail=self.tail.prev
        self.head.prev=temp
    def remove_at_position(self,pos):
        if pos<0 or pos>=self.length():
            raise Exception("Invalid index")
            return
        if pos==self.length()-1:
            self.remove_at_end()
            return
        if pos==0:
            self.remove_at_beginning()
            return
        count=0
        temp=self.head
        while(temp):
            if count==pos-1:
                temp1=temp.next
                temp1.next.prev=temp
                temp.next=temp1.next
                temp1=None
                return
            temp=temp.next
            count+=1
lst=LinkedList()
lst.insert_at_beginning(3)
lst.insert_at_beginning(2)
lst.insert_at_beginning(1)
lst.forward_printing()
lst.reverse_printing()
lst.insert_at_end(4)
lst.insert_at_end(5)
lst.forward_printing()
lst.reverse_printing()
lst.insert_at_position(2,"two")
lst.insert_at_position(4,"four")
lst.forward_printing()
lst.reverse_printing()
lst.insert_multiple_values([10,20,30])
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_beginning()
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_end()
lst.forward_printing()
lst.reverse_printing()
lst.remove_at_position(1)
lst.forward_printing()
lst.reverse_printing()
# Out:
# 1 --> 2 --> 3 -->
# 3 --> 2 --> 1 -->
# 1 --> 2 --> 3 --> 4 --> 5 -->
# 5 --> 4 --> 3 --> 2 --> 1 -->
# 1 --> 2 --> two --> 3 --> four --> 4 --> 5 -->
# 5 --> 4 --> four --> 3 --> two --> 2 --> 1 -->
# 1 --> 2 --> two --> 3 --> four --> 4 --> 5 --> 10 --> 20 --> 30 -->
# 30 --> 20 --> 10 --> 5 --> 4 --> four --> 3 --> two --> 2 --> 1 -->
# 2 --> two --> 3 --> four --> 4 --> 5 --> 10 --> 20 --> 30 -->
# 30 --> 20 --> 10 --> 5 --> 4 --> four --> 3 --> two --> 2 -->
# 2 --> two --> 3 --> four --> 4 --> 5 --> 10 --> 20 -->
# 20 --> 10 --> 5 --> 4 --> four --> 3 --> two --> 2 -->
# 2 --> 3 --> four --> 4 --> 5 --> 10 --> 20 -->
# 20 --> 10 --> 5 --> 4 --> four --> 3 --> 2 -->

# %% [markdown]
# # Hash Table

# %%
#Hash table basic code

class HashTable:
    def __init__(self):
        self.max=100
        self.arr=[None for i in range(self.max)]
    def get_hash(self,data):
        h=0
        for char in data:
            h+=ord(char)
        return h%self.max
    def add(self,key,value):
        h=self.get_hash(key)
        self.arr[h]=value
    def get(self,key):
        h=self.get_hash(key)
        return self.arr[h]
ht=HashTable()
ht.add("Telangana","Hyderabad")
ht.add("Karnataka","Bangalore")
ht.get("Karnataka")
# Out:
# 'Bangalore'

# %%
#Hash Table

class HashTable:
    def __init__(self):
        self.max=100
        self.arr=[None for i in range(self.max)]
    def get_hash(self,data):
        h=0
        for char in data:
            h+=ord(char)
        return h%self.max
    def __setitem__(self,key,value):
        h=self.get_hash(key)
        self.arr[h]=value
    def __getitem__(self,key):
        h=self.get_hash(key)
        return self.arr[h]
    def __delitem__(self,key):
        h=self.get_hash(key)
        self.arr[h]=None
ht=HashTable()
ht["Telangana"]="Hyderabad"
ht["Maharastra"]="Mumbai"
ht["Tamil nadu"]="Chennai"
ht["karnataka"]="Bangalore"
del ht["Maharastra"]

# %%
#Hash table with collision handling using seperate chaining method

class HashTable:
    def __init__(self):
        self.max=100
        self.arr=[[] for i in range(self.max)]
    def get_hash(self,key):
        h=0
        for char in key:
            h+=ord(char)
        return h%self.max
    def __setitem__(self,key,value):
        h=self.get_hash(key)
        for idx,element in enumerate(self.arr[h]):
            if len(element)==2 and element[0]==key:
                self.arr[h][idx]=(key,value)
                break
        else:
            self.arr[h].append((key,value))
    def __getitem__(self,key):
        h=self.get_hash(key)
        for element in self.arr[h]:
            if element[0]==key:
                return element[1]
    def __delitem__(self,key):
        h=self.get_hash(key)
        for idx,element in enumerate(self.arr[h]):
            if element[0]==key:
                del self.arr[h][idx]
                return
ht=HashTable()
ht["Telangana"]="Hyderabad"
ht["Maharastra"]="Mumbai"
ht["Tamil nadu"]="Chennai"
ht["karnataka"]="Bangalore"
ht.arr
del ht["Maharastra"]
ht["Maharastra"]

# %%
# Hash table collision handling using Linear probing
class HashTable:
    def __init__(self):
        self.max=10
        self.arr=[None for i in range(self.max)]
    def get_hash(self,key):
        total=0
        for char in key:
            total+=ord(char)
        return total%self.max
    def __setitem__(self,key,value):
        length=self.get_length()
        h=self.get_hash(key)
        end=self.max
        temp=h
        if length<self.max:
            while temp<end:
                if self.arr[temp]==None or self.arr[temp][0]==key:
                    self.arr[temp]=(key,value)
                    break
                temp+=1
                if temp==end:
                    end=h
                    temp=0
    def __getitem__(self,key):
        for element in self.arr:
            if element!=None and element[0]==key:
                return element[1]
    def __delitem__(self,key):
        for index,element in enumerate(self.arr):
            if element!=None and element[0]==key:
                self.arr[index]=None
    def get_length(self):
        count=0
        for element in self.arr:
            if element!=None:
                count+=1
        return count
h=HashTable()
h['Dhoni']=7
h['Kohli']=18
h['Rohit']=45
h['Dhawan']=25
h['Raina']=3
h['Sachin']=10
h['SKY']=77
h['Jadeja']=8
h['Iyer']=41
h['Rayudu']=9
del h['Iyer']
del h['Jadeja']
h.arr
# Out:
# [('Sachin', 10),
#  ('Raina', 3),
#  None,
#  ('Kohli', 18),
#  ('Rayudu', 9),
#  ('Dhawan', 25),
#  None,
#  ('SKY', 77),
#  ('Dhoni', 7),
#  ('Rohit', 45)]

# %% [markdown]
# # Stack

# %%
#stack using list

stk=[]
while True:
    inp=input("Enter the value(type 'end' to stop): ")
    if inp=="end":
        break
    stk.append(inp)
print("Elements in stack are:",stk)
print("Poping the elements: ")
while len(stk)>0:
    print(stk.pop())
    if len(stk)==0:
        print("Stack is empty")
# Out:
# Enter the value(type 'end' to stop): 56
# Enter the value(type 'end' to stop): 326
# Enter the value(type 'end' to stop): 656
# Enter the value(type 'end' to stop): 556.5
# Enter the value(type 'end' to stop): 354
# Enter the value(type 'end' to stop): end
# Elements in stack are: ['56', '326', '656', '556.5', '354']
# Poping the elements:
# 354
# 556.5
# 656
# 326
# 56
# Stack is empty

# %%
#stack using deque
from collections import deque
class Stack:
    def __init__(self):
        self.container=deque()
    def push(self,value):
        self.container.append(value)
    def pop(self):
        return self.container.pop()
    def is_empty(self):
        return len(self.container)==0
    def peek(self):
        return self.container[-1]
    def size(self):
        return len(self.container)
stk=Stack()
stk.push(45)
stk.push(85)
stk.push(87)
print(stk.peek())
print(stk.pop())
print("Length:",stk.size())
stk.is_empty()
# Out:
# 87
# 87
# Length: 2
# False

# %%
#reversing a string using stack
class Stack:
    def __init__(self):
        self.container=deque()
    def push(self,value):
        self.container.append(value)
    def pop(self):
        return self.container.pop()
    def peek(self):
        return self.container[-1]
    def isEmpty(self):
        return len(self.container)==0
    def size(self):
        return len(self.container)
s=Stack()
string="We will conquere COVID-19"
def reverse_string(string):
    for char in string:
        s.push(char)
    reversed_string=''
    while s.size()!=0:
        reversed_string+=s.pop()
    return reversed_string
print(reverse_string(string))
# Out:
# 91-DIVOC ereuqnoc lliw eW

# %%
# function in python that checks if paranthesis in the string are balanced or not. Possible parantheses are "{}',"()" or "[]"
from collections import deque

class Stack:
    def __init__(self):
        self.container = deque()

    def push(self, val):
        self.container.append(val)

    def pop(self):
        return self.container.pop()

    def peek(self):
        return self.container[-1]

    def is_empty(self):
        return len(self.container) == 0

    def size(self):
        return len(self.container)

def is_match(ch1, ch2):
    match_dict = {
        ')': '(',
        ']': '[',
        '}': '{'
    }
    return match_dict[ch1] == ch2


def is_balanced(s):
    stack = Stack()
    for ch in s:
        if ch=='(' or ch=='{' or ch == '[':
            stack.push(ch)
        if ch==')' or ch=='}' or ch == ']':
            if stack.size()==0:
                return False
            if not is_match(ch,stack.pop()):
                return False

    return stack.size()==0

print(is_balanced("({a+b})"))
print(is_balanced("))((a+b}{"))
print(is_balanced("((a+b))"))
print(is_balanced("((a+g))"))
print(is_balanced("))"))
print(is_balanced("[a+b]*(x+2y)*{gg+kk}"))
# Out:
# True
# False
# True
# True
# False
# True

# %% [markdown]
# # Queue

# %%
#Queue using lists

queue=[]
while True:
    val=input("Enter the value (enter 'end' to stop): ")
    if val=="end":
        break
    queue.append(val)
print("Elements in queue are:",queue)
print("Deque the elements : ")
while len(queue)>0:
    print(queue.pop(0))
    if len(queue)==0:
        print("Queue is empty")
# Out:
# Enter the value (enter 'end' to stop): 45
# Enter the value (enter 'end' to stop): 25
# Enter the value (enter 'end' to stop): 696452
# Enter the value (enter 'end' to stop): 224
# Enter the value (enter 'end' to stop): 452
# Enter the value (enter 'end' to stop): end
# Elements in queue are: ['45', '25', '696452', '224', '452']
# Deque the elements :
# 45
# 25
# 696452
# 224
# 452
# Queue is empty

# %%
#Queue using deque
from collections import deque
class Queue:
    def __init__(self):
        self.buffer=deque()
    def enqueue(self,value):
        self.buffer.append(value)
    def dequeue(self):
        return self.buffer.popleft()
    def is_empty(self):
        return len(self.buffer)==0
    def size(self):
        return len(self.buffer)
q=Queue()
q.enqueue(4612)
q.enqueue(52)
q.enqueue(652)
q.enqueue(874)
q.buffer
q.dequeue()
# Out:
# 4612

# %% [markdown]
# # Tree

# %%
#General tree

class TreeNode:
    def __init__(self,data):
        self.data=data
        self.children=[]
        self.parent=None
    def add_child(self,child):
        child.parent=self
        self.children.append(child)
    def get_level(self):
        level=0
        p=self.parent
        while p:
            level+=1
            p=p.parent
        return level
    def print_tree(self):
        space=' '* self.get_level() *3
        print(space+self.data)
        if self.children:   #if len(self.children)!=0
            for child in self.children:
                child.print_tree()
root=TreeNode("Electronics")
laptop=TreeNode("Laptop")
laptop.add_child(TreeNode("HP"))
laptop.add_child(TreeNode("Dell"))
laptop.add_child(TreeNode("acer"))
root.add_child(laptop)
mobile=TreeNode("Mobiles")
mobile.add_child(TreeNode("Samsung"))
mobile.add_child(TreeNode("Vivo"))
mobile.add_child(TreeNode("apple"))
root.add_child(mobile)
tv=TreeNode("TV")
tv.add_child(TreeNode("Panasonic"))
tv.add_child(TreeNode("LG"))
tv.add_child(TreeNode("MI"))
root.add_child(tv)
root.print_tree()
# Out:
# Electronics
#    Laptop
#       HP
#       Dell
#       acer
#    Mobiles
#       Samsung
#       Vivo
#       apple
#    TV
#       Panasonic
#       LG
#       MI

# %%
#Practice prorgam in General Tree
class TreeNode:
    def __init__(self,data1,data2):
        self.data1=data1
        self.data2=data2
        self.children=[]
        self.parent=None
    def add_child(self,child):
        child.parent=self
        self.children.append(child)
    def print_tree(self,op):
        space=' '*self.get_level()*3
        if op=="Name":
            print(space+self.data1)
            if self.children:
                for child in self.children:
                    child.print_tree(op)
        elif op=="Designation":
            print(space+self.data2)
            if self.children:
                for child in self.children:
                    child.print_tree(op)
        elif op=="Both":
            print(space+self.data1+"("+self.data2+")")
            if self.children:
                for child in self.children:
                    child.print_tree(op)
            
    def get_level(self):
        level=0
        p=self.parent
        while p:
            level+=1
            p=p.parent
        return level
root=TreeNode("Nilupul","CEO")
l21=TreeNode("Chinmay","CTO")
l22=TreeNode("Gels","HR Head")
l31=TreeNode("Vishwa","Infrastructure Head")
l32=TreeNode("Aamir","Application Head")
l33=TreeNode("Peter","Recruitment Manager")
l34=TreeNode("Waqas","Policy Manager")
l41=TreeNode("Dhaval","Cloud Manager")
l42=TreeNode("Abhijit","App Manager")
root.add_child(l21)
root.add_child(l22)
l21.add_child(l31)
l21.add_child(l32)
l31.add_child(l41)
l31.add_child(l42)
l22.add_child(l33)
l22.add_child(l34)
root.print_tree("Both")
# Out:
# Nilupul(CEO)
#    Chinmay(CTO)
#       Vishwa(Infrastructure Head)
#          Dhaval(Cloud Manager)
#          Abhijit(App Manager)
#       Aamir(Application Head)
#    Gels(HR Head)
#       Peter(Recruitment Manager)
#       Waqas(Policy Manager)

# %% [markdown]
# # Binary Search Tree

# %%
#Binary Search Tree (in order traversal)

class BinarySearchTree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    def add_child(self,value):
        if self.data==value:
            return
        if value<self.data:
            if self.left:
                self.left.add_child(value)
            else:
                self.left=BinarySearchTree(value)
        if value>self.data:
            if self.right:
                self.right.add_child(value)
            else:
                self.right=BinarySearchTree(value)
    def in_order_traversal(self):
        elements=[]
        if self.left:
            elements+=self.left.in_order_traversal()
        elements.append(self.data)
        if self.right:
            elements+=self.right.in_order_traversal()
        return elements
    def find_min(self):
        if self.left:
            return self.left.find_min()
        return self.data
    def find_max(self):
        if self.right:
            return self.right.find_max()
        return self.data
    def search(self,value):
        if value<self.data:
            if self.left:
                return self.left.search(value)
            else:
                return False
        elif value>self.data:
            if self.right:
                return self.right.search(value)
            else:
                return False
        return True
    def delete(self,value):
        if value>self.data:
            if self.right:
                self.right=self.right.delete(value)
        elif value<self.data:
            if self.left:
                self.left=self.left.delete(value)
        else:
            if self.left == None and self.right == None:
                return None
            if self.left == None:
                return self.right
            if self.right == None:
                return self.left
            min_val=self.right.find_min()
            self.data=min_val
            self.right=self.right.delete(min_val)
        return self
    def isBST(self): # to check whether it is a BinarySearchTree or not (my code)
        if self.left and self.right:
            if self.data<=self.left.data or self.data>=self.right.data:
                return False
            return self.left.isBST() and self.right.isBST()
        
        elif self.left:
            if self.data<=self.left.data:
                return False
            return self.left.isBST()
        elif self.right:
            if self.data>=self.right.data:
                return 
            return self.right.isBST()
        return True
elements=[42,62,2,6,58,96,84,15]
root=BinarySearchTree(elements[0])
for i in range(1,len(elements)):
    root.add_child(elements[i])
print(root.in_order_traversal())
print("Minimum:",root.find_min())
print("Maximum:",root.find_max())
root.delete(58)
print("After deleting 58")
print(root.in_order_traversal())
root.search(96)
print("Is it a Binary Search Tree ? :",root.isBST())
# Out:
# [2, 6, 15, 42, 58, 62, 84, 96]
# Minimum: 2
# Maximum: 96
# After deleting 58
# [2, 6, 15, 42, 62, 84, 96]
# Is it a Binary Search Tree ? : True

# %%
#Binary Search Tree (pre order traversal)

class BinarySearchTree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    def add_child(self,value):
        if self.data==value:
            return
        if value<self.data:
            if self.left:
                self.left.add_child(value)
            else:
                self.left=BinarySearchTree(value)
        if value>self.data:
            if self.right:
                self.right.add_child(value)
            else:
                self.right=BinarySearchTree(value)
    def pre_order_traversal(self):
        elements=[]
        elements.append(self.data)
        if self.left:
            elements+=self.left.pre_order_traversal()
        if self.right:
            elements+=self.right.pre_order_traversal()
        return elements
elements=[42,62,2,6,58,96,84,15]
root=BinarySearchTree(elements[0])
for i in range(1,len(elements)):
    root.add_child(elements[i])
print(root.pre_order_traversal())
# Out:
# [42, 2, 6, 15, 62, 58, 96, 84]

# %%
#Binary Search Tree (post order traversal)

class BinarySearchTree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    def add_child(self,value):
        if self.data==value:
            return
        if value<self.data:
            if self.left:
                self.left.add_child(value)
            else:
                self.left=BinarySearchTree(value)
        if value>self.data:
            if self.right:
                self.right.add_child(value)
            else:
                self.right=BinarySearchTree(value)
    def post_order_traversal(self):
        elements=[]
        if self.left:
            elements+=self.left.post_order_traversal()
        if self.right:
            elements+=self.right.post_order_traversal()
        elements.append(self.data)
        return elements
elements=[42,62,2,6,58,96,84,15]
root=BinarySearchTree(elements[0])
for i in range(1,len(elements)):
    root.add_child(elements[i])
print(root.post_order_traversal())
# Out:
# [15, 6, 2, 58, 84, 96, 62, 42]

# %%
#Binary Search Tree (in order traversal)

class BinarySearchTree:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
    def add_child(self,value):
        if self.data==value:
            return
        if value<self.data:
            if self.left:
                self.left.add_child(value)
            else:
                self.left=BinarySearchTree(value)
        if value>self.data:
            if self.right:
                self.right.add_child(value)
            else:
                self.right=BinarySearchTree(value)
    def in_order_traversal(self):
        elements=[]
        if self.left:
            elements+=self.left.in_order_traversal()
        elements.append(self.data)
        if self.right:
            elements+=self.right.in_order_traversal()
        return elements
    def find_min(self):
        if self.left:
            return self.left.find_min()
        return self.data
    def find_max(self):
        if self.right:
            return self.right.find_max()
        return self.data
    def delete(self,value):
        if value<self.data:
            if self.left:
                self.left.delete(value)
        elif value>self.data:
            if self.right:
                self.right.delete(value)
        else:
            if self.left is None and self.right is None:
                return None
            if self.left is None:
                return self.right
            if self.right is None:
                return self.left
            max_value=self.left.find_max()
            self.data=max_value
            self.left=self.left.delete(max_value)
        return self
            
                
elements=[42,62,2,6,58,96,84,15]
root=BinarySearchTree(elements[0])
for i in range(1,len(elements)):
    root.add_child(elements[i])
print(root.in_order_traversal())
print("Minimum:",root.find_min())
print("Maximum:",root.find_max())
root.delete(58)
print(root.in_order_traversal())
# Out:
# [2, 6, 15, 42, 58, 62, 84, 96]
# Minimum: 2
# Maximum: 96
# [2, 6, 15, 42, 58, 62, 84, 96]

# %% [markdown]
# # Graph

# %%
class Graph:
    def __init__(self,routes):
        self.routes=routes
        self.routes_dict={}
        for start,end in self.routes:
            if start not in self.routes_dict:
                self.routes_dict[start]=[end]
            else:
                self.routes_dict[start].append(end)
    def get_paths(self,start,end,path=[]):
        path=path+[start]
        if start==end:
            return [path]
        if start not in self.routes_dict:
            return []
        paths=[]
        for route in self.routes_dict[start]:
            if route not in path:
                new_paths=self.get_paths(route,end,path)
                for p in new_paths:
                    paths.append(p)
        return paths
    def get_shortest_path(self,start,end,path=[]):
        path=path+[start]
        if start==end:
            return path
        if start not in self.routes_dict:
            return []
        shortest_path=None
        for route in self.routes_dict[start]:
            if route not in path:
                sp=self.get_shortest_path(route,end,path)
                if sp:
                    if shortest_path==None or len(sp)<len(shortest_path):
                        shortest_path=sp
        return shortest_path

routes = [
        ("Mumbai","Pune"),
        ("Mumbai", "Surat"),
        ("Surat", "Bangaluru"),
        ("Pune","Hyderabad"),
        ("Pune","Mysuru"),
        ("Hyderabad","Bangaluru"),
        ("Hyderabad", "Chennai"),
        ("Mysuru", "Bangaluru"),
        ("Chennai", "Bangaluru")
    ]
routes_graph=Graph(routes)
start="Mumbai"
end="Bangaluru"
print("Shortest : ",routes_graph.get_shortest_path(start,end))
print("\nAll available paths : ")
routes_graph.get_paths(start,end)
# Out:
# Shortest :  ['Mumbai', 'Surat', 'Bangaluru']
#
# All available paths :
# [['Mumbai', 'Pune', 'Hyderabad', 'Bangaluru'],
#  ['Mumbai', 'Pune', 'Hyderabad', 'Chennai', 'Bangaluru'],
#  ['Mumbai', 'Pune', 'Mysuru', 'Bangaluru'],
#  ['Mumbai', 'Surat', 'Bangaluru']]

# %%
#my code
routes = [
        ("Mumbai","Pune"),
        ("Mumbai", "Surat"),
        ("Surat", "Bangaluru"),
        ("Pune","Hyderabad"),
        ("Pune","Mysuru"),
        ("Hyderabad","Bangaluru"),
        ("Hyderabad", "Chennai"),
        ("Mysuru", "Bangaluru"),
        ("Chennai", "Bangaluru")
    ]
routes_dict={}
for start,end in routes:
    if start not in routes_dict.keys():
        routes_dict[start]=[end]
    else:
        routes_dict[start].append(end)

#to get all the possible paths
paths=[]
def get_routes(start,end,visited=""):
    visited+=" "+start
    if start==end:
        paths.append(visited.split())
    if start not in routes_dict.keys():
        return
    for route in routes_dict[start]:
        if route not in visited:
            get_routes(route,end,visited)
            
 #to get the shortest path           
shortest_path=[]
def get_shortest_path(start,end,visited=""):
    visited+=" "+start
    if start==end:
        temp=visited.split()
        global shortest_path #if it is not declared as global, it is throwing an error
        if len(shortest_path)!=0:
            if len(temp)<len(shortest_path):
                shortest_path=temp
        else:
            shortest_path=temp
    if start not in routes_dict.keys():
        return
    for route in routes_dict[start]:
        if route not in visited:
            get_shortest_path(route,end,visited)
get_routes("Mumbai","Bangaluru")
get_shortest_path("Mumbai","Bangaluru")
print("All paths :",paths)
print("Shortest path :",shortest_path)
# Out:
# All paths : [['Mumbai', 'Pune', 'Hyderabad', 'Bangaluru'], ['Mumbai', 'Pune', 'Hyderabad', 'Chennai', 'Bangaluru'], ['Mumbai', 'Pune', 'Mysuru', 'Bangaluru'], ['Mumbai', 'Surat', 'Bangaluru']]
# Shortest path : ['Mumbai', 'Surat', 'Bangaluru']
