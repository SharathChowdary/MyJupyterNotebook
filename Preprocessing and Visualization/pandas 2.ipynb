# %% [markdown]
# # Data Science

# %% [markdown]
# Data science or Data Analytics is the process of analyzing large set of data points to get answers on questions related to that dataset.

# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a python module that makes data science easy and effective

# %% [markdown]
# The process of cleaning raw data or messy data is called data munging or data wragling

# %%
#importing a csv file using pandas
import pandas as pd
import numpy as np
data=pd.read_csv("datasets/pokemon.csv")
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
#extracting first five rows
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#extracting last five rows
data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
#Extracting list of columns
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Extracting Name column
data.Name #data["Name"]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
data['Attack'].max()
# Out:
# 190

# %%
#finding the name that has a highest speed
data[data['Speed']==data['Speed'].max()]['Name']
# Out:
# 431    DeoxysSpeed Forme
# Name: Name, dtype: object

# %%
#Extracting the row that has an highest speed
data.loc[data['Speed']==data['Speed'].max()]
#data[data['Speed']==data['Speed'].max()] --> can also be used
# Out:
#        #               Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 431  386  DeoxysSpeed Forme  Psychic    NaN    600  50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       95       90    180           3       True

# %%
#Extracting all rows which has Type 1 as "Fire"
#data[data['Type 1']=="Fire"]
data.loc[data['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
#extracting all rows where Speed>150
data[data.Speed>150]
# Out:
#        #               Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 315  291            Ninjask      Bug  Flying    456  61      90       45
# 431  386  DeoxysSpeed Forme  Psychic     NaN    600  50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 315       50       50    160           3      False
# 431       95       90    180           3       True

# %%
import numpy as np
data.loc[data['Type 2']==np.NaN]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
#Grouping the data based on column "Type 1"
data1=data.groupby("Type 1")
data1

# %%
#count of all values of each column
data1.count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
#Size of each type
data1.size()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# dtype: int64

# %%
#fetching rows of maximum speed for every Type
data1.max("Speed")
# Out:
#             #  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       666    600   86     185      230      135      230    160
# Dark      717    680  126     150      125      140      130    125
# Dragon    718    780  125     180      130      180      150    120
# Electric  702    610   90     123      115      165      110    140
# Fairy     716    680  126     131       95      131      154     99
# Fighting  701    625  144     145       95      140      110    118
# Fire      721    680  115     160      140      159      154    126
# Flying    715    580   85     115       80      125       90    123
# Ghost     711    680  150     165      145      170      135    130
# Grass     673    630  123     132      131      145      129    145
# Ground    645    770  115     180      160      150      120    120
# Ice       713    580  110     130      184      130      200    110
# Normal    676    720  255     160      126      135      135    135
# ...

# %% [markdown]
# # Working with dataframes

# %% [markdown]
# Dataframe is a main object in Pandas.
# It is used to represent data with rows and columns

# %%
#creating a DataFrame
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df=pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#converting Dataframe to csv
df.to_csv("weather_sample.csv")

# %%
#slicing
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
#finding the shape
rows,columns=df.shape
print(rows,columns)
# Out:
# 6 4

# %%
#getting an index
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#setting index
lst=['a','b','c','d','e','f']
df['index']=lst
df
# Out:
#         day  temperature  windspeed  event index
# 0  1/1/2017           32          6   Rain     a
# 1  1/2/2017           35          7  Sunny     b
# 2  1/3/2017           28          2   Snow     c
# 3  1/4/2017           24          7   Snow     d
# 4  1/5/2017           32          4   Rain     e
# 5  1/6/2017           31          2  Sunny     f

# %%
df.set_index("index")
# Out:
#             day  temperature  windspeed  event
# index
# a      1/1/2017           32          6   Rain
# b      1/2/2017           35          7  Sunny
# c      1/3/2017           28          2   Snow
# d      1/4/2017           24          7   Snow
# e      1/5/2017           32          4   Rain
# f      1/6/2017           31          2  Sunny

# %%
#reseting the index
df.reset_index()
# Out:
#    level_0       day  temperature  windspeed  event index
# 0        0  1/1/2017           32          6   Rain     a
# 1        1  1/2/2017           35          7  Sunny     b
# 2        2  1/3/2017           28          2   Snow     c
# 3        3  1/4/2017           24          7   Snow     d
# 4        4  1/5/2017           32          4   Rain     e
# 5        5  1/6/2017           31          2  Sunny     f

# %%
#type of dataframe
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#type of a column in dataframe
type(df['temperature'])
# Out:
# pandas.core.series.Series

# %%
#extracting few columns
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
#  4   index        6 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 368.0+ bytes

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
#extracting day and temperature which has maximum temperature
df[['day','temperature']][df.temperature==df.temperature.max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %% [markdown]
# # Different ways of creating DataFrames

# %%
#by reading csv file
data=pd.read_csv("weather_sample.csv")
data
# Out:
#    Unnamed: 0       day  temperature  windspeed  event
# 0           0  1/1/2017           32          6   Rain
# 1           1  1/2/2017           35          7  Sunny
# 2           2  1/3/2017           28          2   Snow
# 3           3  1/4/2017           24          7   Snow
# 4           4  1/5/2017           32          4   Rain
# 5           5  1/6/2017           31          2  Sunny

# %%
#using dictionary
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
data=pd.DataFrame(weather_data)
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#using list of tuples
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
data=pd.DataFrame(weather_data,columns=['day','temperature','windspeed','event'])
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
#reading xlsx file
data=pd.read_excel("datasets/weather_data.xlsx","Sheet1")
data
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
#using list of dictionaries
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# # Reading and writing csv and excel files

# %%
#Reading csv files
data=pd.read_excel("stock_data.xlsx","Sheet1")
data.to_csv("stock_data.csv",index=False)#index=False will not add extra index
#data.to_csv("stock_data.csv",index=False,columns=["col1_name","col2_name"]) --> it will export only mentioned colums
#data.to_csv("stock_data.csv",index=False,header=False) --> it will not export the header
#data.to_csv("stock_data.csv",index=False,header=[0,1])-->indicates that 0,1 are headings or headers

# %%
data1=pd.read_csv("stock_data.csv")
#data1=pd.read_csv("stock_data.csv",skiprows=1) --> It will remove the first row
#data1=pd.read_csv("stock_data.csv",header=1) --> It will start from 2nd header
#data1=pd.read_csv("stock_data.csv",header=None) --> It will remove the heading 
#data1=pd.read_csv("stock_data.csv",names=["col1_name","col2_name","col3_name"]) --> assining names to the headers
data1
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
data1=pd.read_csv("stock_data.csv",nrows=3)#only 3 rows are loaded
data1
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
data1=pd.read_csv("stock_data.csv",na_values=['not available','n.a.'])#this will convert 'not available','n.a.' values to NaN
data1
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
#it is always better to pass dictionary because we can set NaN values for each column based on its requirements
data1=pd.read_csv("stock_data.csv",na_values={'eps':['not available','n.a.'],'revenue':['not available','n.a.',-1],'price':['not available','n.a.']})
data1
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0           n.a.
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
#loading an excel
data2=pd.read_excel("stock_data.xlsx","Sheet1")
data2
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#converting to excel
data2.to_excel("new_stock_data.xlsx",sheet_name='stocks')
#data2.to_excel("new_stock_data.xlsx",sheet_name='stocks',startrow=2,startcol=2) --> sheet starts from 2nd row and 3rd column

# %%
#writing different dataframes as different sheets in a single excel file
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %% [markdown]
# # Handling NaN values

# %%
import pandas as pd
data=pd.read_csv("datasets/weather.csv")
data
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
#checking the data type of "day" column
type(data['day'][0])
# Out:
# str

# %%
#converting data type of "day" to dates
data=pd.read_csv("datasets/weather.csv",parse_dates=['day'])
data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
#setting day as an index
data.set_index("day",inplace=True)
data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#extracting all the rows that has NaN values
data[data.isna().any(axis=1)]
# Out:
#             temperature  windspeed  event
# day
# 2017-01-04          NaN        9.0  Sunny
# 2017-01-05         28.0        NaN   Snow
# 2017-01-06          NaN        7.0    NaN
# 2017-01-07         32.0        NaN   Rain
# 2017-01-08          NaN        NaN  Sunny
# 2017-01-09          NaN        NaN    NaN

# %%
#filling NaN values with 0
data1=data.fillna(0)
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling NaN values using dictionary
data1=data.fillna({
    'temperature':0,
    'windspeed':0,
    'event':"no event"
})
data1
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
#filling NaN values with its above values
data1=data.fillna(method="ffill")
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling NaN values with its below values
data1=data.fillna(method="bfill")
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling NaN values with its right side values
data1=data.fillna(method="bfill",axis='columns')
data1
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         9.0       9.0   Sunny
# 2017-01-05        28.0      Snow    Snow
# 2017-01-06         7.0       7.0     NaN
# 2017-01-07        32.0      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %%
#filling NaN values with its left side values
data1=data.fillna(method="ffill",axis='columns')
data1
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         NaN       9.0   Sunny
# 2017-01-05        28.0      28.0    Snow
# 2017-01-06         NaN       7.0     7.0
# 2017-01-07        32.0      32.0    Rain
# 2017-01-08         NaN       NaN   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %%
data1=data.fillna(method="ffill",limit=1)#limit=1 --> above value is carried only 1 time
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling NaN values with mean of above and below values
data1=data.interpolate()
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
#filling NaN values based on their dates also
#best method for filling NaN values *************************************************
data1=data.interpolate(method="time")
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
#removing all the rows that are having atleast one NaN value
data1=data.dropna()
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#dropping rows which has all columns as NaN
data1=data.dropna(how="all")
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#keeping the rows that has atleast 1 non NaN value
data1=data.dropna(thresh=1)
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#keeping the rows that has atleast 2 non NaN values
data1=data.dropna(thresh=2)
data1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
data
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#filling missing dates
"""(or)
dt=pd.date_range('2017-01-01','2017-01-11')
data1=data.reindex(dt)
can also be used
"""
dt=pd.date_range('2017-01-01','2017-01-11')
idx=pd.DatetimeIndex(dt)
data1=data.reindex(idx)
data1
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# # Replace function

# %%
import numpy as np

# %%
lst=[(1/1/2017,32,6,"Rain"),(1/2/2017,-99999,7,"Sunny"),(1/3/2017,28,-99999,"Snow"),(1/4/2017,-99999,7,0),(1/5/2017,32,-99999,"Rain"),(1/6/2017,31,2,"Sunny"),(1/6/2017,34,5,0)]
data=pd.DataFrame(lst,columns=["day","temperature","windspeed","event"])
data
# Out:
#         day  temperature  windspeed  event
# 0  0.000496           32          6   Rain
# 1  0.000248       -99999          7  Sunny
# 2  0.000165           28     -99999   Snow
# 3  0.000124       -99999          7      0
# 4  0.000099           32     -99999   Rain
# 5  0.000083           31          2  Sunny
# 6  0.000083           34          5      0

# %%
#replacing -99999 with 0
data1=data.replace(-99999,np.NaN)
data1
# Out:
#         day  temperature  windspeed  event
# 0  0.000496         32.0        6.0   Rain
# 1  0.000248          NaN        7.0  Sunny
# 2  0.000165         28.0        NaN   Snow
# 3  0.000124          NaN        7.0      0
# 4  0.000099         32.0        NaN   Rain
# 5  0.000083         31.0        2.0  Sunny
# 6  0.000083         34.0        5.0      0

# %%
lst=[(1/1/2017,32,6,"Rain"),(1/2/2017,-99999,7,"Sunny"),(1/3/2017,28,-99999,"Snow"),(1/4/2017,-88888,7,0),(1/5/2017,32,-88888,"Rain"),(1/6/2017,31,2,"Sunny"),(1/6/2017,34,5,0)]
data=pd.DataFrame(lst,columns=["day","temperature","windspeed","event"])
data
# Out:
#         day  temperature  windspeed  event
# 0  0.000496           32          6   Rain
# 1  0.000248       -99999          7  Sunny
# 2  0.000165           28     -99999   Snow
# 3  0.000124       -88888          7      0
# 4  0.000099           32     -88888   Rain
# 5  0.000083           31          2  Sunny
# 6  0.000083           34          5      0

# %%
#replacing both -88888 and -99999 with np.NaN values
data1=data.replace([-88888,-99999],np.NaN)
data1
# Out:
#         day  temperature  windspeed  event
# 0  0.000496         32.0        6.0   Rain
# 1  0.000248          NaN        7.0  Sunny
# 2  0.000165         28.0        NaN   Snow
# 3  0.000124          NaN        7.0      0
# 4  0.000099         32.0        NaN   Rain
# 5  0.000083         31.0        2.0  Sunny
# 6  0.000083         34.0        5.0      0

# %%
#replacing values based on columns using dictionary
data1=data.replace({'temperature':[-88888,-99999],
                   'windspeed':[-88888,-99999],
                    'event':0
                   },np.NaN)
data1
# Out:
#         day  temperature  windspeed  event
# 0  0.000496         32.0        6.0   Rain
# 1  0.000248          NaN        7.0  Sunny
# 2  0.000165         28.0        NaN   Snow
# 3  0.000124          NaN        7.0    NaN
# 4  0.000099         32.0        NaN   Rain
# 5  0.000083         31.0        2.0  Sunny
# 6  0.000083         34.0        5.0    NaN

# %%
#replacing values using dictionary 
lst=[(1/1/2017,32,6,"Rain"),(1/2/2017,-99999,7,"Sunny"),(1/3/2017,28,-99999,"Snow"),(1/4/2017,-88888,7,0),(1/5/2017,32,-88888,"Rain"),(1/6/2017,31,2,"Sunny"),(1/6/2017,34,5,0)]
data=pd.DataFrame(lst,columns=["day","temperature","windspeed","event"])
data
# Out:
#         day  temperature  windspeed  event
# 0  0.000496           32          6   Rain
# 1  0.000248       -99999          7  Sunny
# 2  0.000165           28     -99999   Snow
# 3  0.000124       -88888          7      0
# 4  0.000099           32     -88888   Rain
# 5  0.000083           31          2  Sunny
# 6  0.000083           34          5      0

# %%
data1=data.replace({
    -88888:0,
    -99999:0,
    0:"no event"
})
data1
# Out:
#         day  temperature  windspeed     event
# 0  0.000496           32          6      Rain
# 1  0.000248            0          7     Sunny
# 2  0.000165           28          0      Snow
# 3  0.000124            0          7  no event
# 4  0.000099           32          0      Rain
# 5  0.000083           31          2     Sunny
# 6  0.000083           34          5  no event

# %%
lst=[(1/1/2017,"43 F",6,"Rain"),(1/2/2017,-99999,"7 mph","Sunny"),(1/3/2017,"28 C",-99999,"Snow"),(1/4/2017,-88888,"7 mph",0),(1/5/2017,32,-88888,"Rain"),(1/6/2017,31,2,"Sunny"),(1/6/2017,34,5,0)]
data=pd.DataFrame(lst,columns=["day","temperature","windspeed","event"])
data
# Out:
#         day temperature windspeed  event
# 0  0.000496        43 F         6   Rain
# 1  0.000248      -99999     7 mph  Sunny
# 2  0.000165        28 C    -99999   Snow
# 3  0.000124      -88888     7 mph      0
# 4  0.000099          32    -88888   Rain
# 5  0.000083          31         2  Sunny
# 6  0.000083          34         5      0

# %%
#removing units such as F,C, mph
data1=data.replace('[A-Za-z]'," ",regex=True)
data1
# Out:
#         day temperature windspeed  event
# 0  0.000496        43           6
# 1  0.000248      -99999     7
# 2  0.000165        28      -99999
# 3  0.000124      -88888     7          0
# 4  0.000099          32    -88888
# 5  0.000083          31         2
# 6  0.000083          34         5      0

# %%
#removing units using dictionary
data1=data.replace({
    'temperature':'[A-Za-z]',
    'windspeed':'[A-Za-z]'
}," ",regex=True)
data1
# Out:
#         day temperature windspeed  event
# 0  0.000496        43           6   Rain
# 1  0.000248      -99999     7      Sunny
# 2  0.000165        28      -99999   Snow
# 3  0.000124      -88888     7          0
# 4  0.000099          32    -88888   Rain
# 5  0.000083          31         2  Sunny
# 6  0.000083          34         5      0

# %%
#replacing string with values
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'below average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#            score  student
# 0    exceptional      rob
# 1        average     maya
# 2           good  parthiv
# 3           poor      tom
# 4  below average   julian
# 5    exceptional    erica

# %%
df1=df.replace(['exceptional','good','average','below average','poor'],[5,4,3,2,1])
df1
# Out:
#    score  student
# 0      5      rob
# 1      3     maya
# 2      4  parthiv
# 3      1      tom
# 4      2   julian
# 5      5    erica

# %% [markdown]
# # groupby() function

# %%
import pandas as pd

# %%
lst=[
("1/1/2017","new york",32,6,"Rain"),
("1/2/2017","new york",36,7,"Sunny"),
("1/3/2017","new york",28,12,"Snow"),
("1/4/2017","new york",33,7,"Sunny"),
("1/1/2017","mumbai",90,5,"Sunny"),
("1/2/2017","mumbai",85,12,"Fog"),
("1/3/2017","mumbai",87,15,"Fog"),
("1/4/2017","mumbai",92,5,"Rain"),
("1/1/2017","paris",45,20,"Sunny"),
("1/2/2017","paris",50,13,"Cloudy"),
("1/3/2017","paris",54,8,"Cloudy"),
("1/4/2017","paris",42,10,"Cloudy")
]
df=pd.DataFrame(lst)

# %%
df.columns=["day","city","temperature","windspeed","event"]
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
data=df.groupby('city')
data

# %%
#printing grouped data seperately
for groupname,grouptable in data:
    print(groupname)
    print(grouptable)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
#fetching individual group
data.get_group('paris')
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
#getting maximum values from each column
data.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
#getting average values for each column
data.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
#getting maximum temperature for each group
data.temperature.max()
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
data.max('temperature')
# Out:
#           temperature  windspeed
# city
# mumbai             92         15
# new york           36         12
# paris              54         20

# %%
data.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %% [markdown]
# # Concat() function

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#concatinating two dataframes
df=pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#Getting continous indexing
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
#adding key to the each individual dataframe
#"keys" arguement doesn't work along with "ignore_index" 
df=pd.concat([india_weather,us_weather],keys=['India',"Usa"])
df
# Out:
#              city  temperature  humidity
# India 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# Usa   0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
#fecting each dataframe individually
df.loc["India"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
df.loc['Usa']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature_df=pd.DataFrame(
    {
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30]
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df=pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "windspeed":[12,14,11]
})
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai         12
# 1     delhi         14
# 2  banglore         11

# %%
df=pd.concat([temperature_df,windspeed_df])
df
# Out:
#        city  temperature  windspeed
# 0    mumbai         32.0        NaN
# 1     delhi         45.0        NaN
# 2  banglore         30.0        NaN
# 0    mumbai          NaN       12.0
# 1     delhi          NaN       14.0
# 2  banglore          NaN       11.0

# %%
#concatinating horizontally
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai         12
# 1     delhi           45     delhi         14
# 2  banglore           30  banglore         11

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
})
windspeed_df
# Out:
#      city  windspeed
# 0   delhi          7
# 1  mumbai         12

# %%
#concatinating while order of cities is not correct
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
#Here the cities are different in single row and hence it can be handled by passing index values to the dataframes
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32   delhi        7.0
# 1     delhi           45  mumbai       12.0
# 2  banglore           30     NaN        NaN

# %%
#concatinating using index
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
#concatinating Series with DataFrame
s=pd.Series(["Humid","Dry","Rain"],name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df=pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %% [markdown]
# # Merge() function

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
#merging two dataframes
df=pd.merge(df1,df2,on="city")
df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
#by default it performs inner join
df=pd.merge(df1,df2,on="city")
df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
#outer join
df=pd.merge(df1,df2,on="city",how='outer')
df
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
#left join
df=pd.merge(df1,df2,on="city",how='left')
df
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
#right join
df=pd.merge(df1,df2,on="city",how='right')
df
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
#indicator flag--> useful to indicate the row belongs to which dataframe
#outer join
df=pd.merge(df1,df2,on="city",how='outer',indicator=True)
df
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
#Adding suffixes
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
#default suffixes are "_x" and "_y"
df=pd.merge(df1,df2,on='city',how="outer")
df
# Out:
#         city  temperature_x  humidity_x  temperature_y  humidity_y
# 0   new york           21.0        65.0           14.0        68.0
# 1    chicago           14.0        68.0           21.0        65.0
# 2    orlando           35.0        71.0            NaN         NaN
# 3  baltimore           38.0        75.0            NaN         NaN
# 4  san diego            NaN         NaN           35.0        71.0

# %%
#adding our own suffix
df=pd.merge(df1,df2,on='city',how="outer",suffixes=["_left","_right"])
df
# Out:
#         city  temperature_left  humidity_left  temperature_right  \
# 0   new york              21.0           65.0               14.0
# 1    chicago              14.0           68.0               21.0
# 2    orlando              35.0           71.0                NaN
# 3  baltimore              38.0           75.0                NaN
# 4  san diego               NaN            NaN               35.0
#
#    humidity_right
# 0            68.0
# 1            65.0
# 2             NaN
# 3             NaN
# 4            71.0

# %% [markdown]
# # join() function

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1.set_index('city',inplace=True)
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2.set_index('city',inplace=True)
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df=df1.join(df2,lsuffix='_left',rsuffix='_right')
df
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75

# %% [markdown]
# # pivot() function

# %% [markdown]
# pivot allows you to transform or reshape the data

# %%
import pandas as pd
lst=[
("5/1/2017","new york",65,56),
("5/2/2017","new york",66,58),
("5/3/2017","new york",68,60),
("5/1/2017","mumbai",75,80),
("5/2/2017","mumbai",78,83),
("5/3/2017","mumbai",82,85),
("5/1/2017","beijing",80,26),
("5/2/2017","beijing",77,30),
("5/3/2017","beijing",79,35),
]
data=pd.DataFrame(lst,columns=["date","city","temperature","humidity"])
data
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
#creating table with city in rows and date in columns
data.pivot(index='city',columns='date')
#data.pivot('city','date') --> can also be used
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
#creating table with dates in rows and city in columns
data.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
#extracting only temperature
data.pivot(index='city',columns='date',values='temperature')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         80        77        79
# mumbai          75        78        82
# new york        65        66        68

# %%
#extracting only humidity
data.pivot(index='city',columns='date',values='humidity')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %% [markdown]
# # pivot_table() function
# pivot table is used to summarize and aggregate the data inside the dataframe

# %%
lst=[
("5/1/2017","new york",65,56),
("5/1/2017","new york",61,54),
("5/2/2017","new york",70,60),
("5/2/2017","new york",72,62),
("5/1/2017","mumbai",75,80),
("5/1/2017","mumbai",78,83),
("5/2/2017","mumbai",82,85),
("5/2/2017","mumbai",80,26)
]
data=pd.DataFrame(lst,columns=["date","city","temperature","humidity"])
data
#here the multiple values are there for a single date
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
#mean values are returned for the same dates
#by default "aggfunc" is 'mean'
data.pivot_table(index='city',columns='date')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
#getting sum of values for the same day
data.pivot_table(index='city',columns='date',aggfunc='sum')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
#getting the count of values for the same date
data.pivot_table(index='city',columns='date',aggfunc='count')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai          2        2           2        2
# new york        2        2           2        2

# %%
#getting aggregate values for all rows and columns
data.pivot_table(index='city',columns='date',margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
lst=[
("5/1/2017","new york",65,56),
("5/2/2017","new york",61,54),
("5/3/2017","new york",70,60),
("12/1/2017","new york",30,50),
("12/2/2017","new york",28,52),
("12/3/2017","new york",25,51)
]
data=pd.DataFrame(lst,columns=["date","city","temperature","humidity"])
data
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
#converting string to date format
data['date']=pd.to_datetime(data['date'])

# %%
#fetching average humidity and temperature in the month
data.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# # melt() function
# for reshaping the data

# %%
import pandas as pd
lst=[
("Monday",32,75,41),
("Tuesday",30,77,43),
("Wednesday",28,75,45),
("Thursday",22,82,38),
("Friday",30,83,30),
("Saturday",20,81,45),
("Sunday",25,77,47)
]
df=pd.DataFrame(lst,columns=["day","chicago","chennai","berlin"])
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
#reshaping the table
df1=pd.melt(df,id_vars=['day'])
#df1=pd.melt(df,['day']) --> can also be used
#df1=pd.melt(df,'day') --> can also be used
df1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
#extracting particular cities
df1[df1['variable']=="chicago"]
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
#assigning names to the columns
df1=pd.melt(df,id_vars=['day'],var_name='city',value_name='temperature')
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# # stack() function
# The stack() method reshapes the DataFrame into a table with a new inner-most level of rows for each column.

# %%
df=pd.read_excel("datasets/stocks_for_stack_method.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
#by default it takes inner most level(i.e company row) to convert into columns
df1=df.stack()
df1
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
#explicitly converting top header as a column
df1=df.stack(level=0)
df1
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
df=pd.read_excel("datasets/stocks_for_stack_method_2.xlsx",header=[0,1,2])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
stacked_data=df.stack()
stacked_data
# Out:
#             Income Statement           Price Ratios  \
#                   Net Profit Net Sales        Price
# 0 Company                NaN       NaN          NaN
#   Facebook              0.80      2.60        155.0
#   Google                5.43     20.00        955.0
#   Microsoft             4.56     18.70         66.0
# 1 Company                NaN       NaN          NaN
#   Facebook              0.97      3.10        150.0
#   Google                5.89     22.00        987.0
#   Microsoft             5.10     21.30         69.0
# 2 Company                NaN       NaN          NaN
#   Facebook              1.20      4.30        153.0
#   Google                6.10     24.00        963.0
#   Microsoft             5.43     21.45         62.0
# 3 Company                NaN       NaN          NaN
#   Facebook              1.67      6.70        155.0
#   Google                6.50     26.00       1000.0
#   Microsoft             5.89     21.88         61.0
# ...

# %%
#unstacking the data 
stacked_data.unstack()
# Out:
#   Income Statement                                                      \
#         Net Profit                           Net Sales
#            Company Facebook Google Microsoft   Company Facebook Google
# 0              NaN     0.80   5.43      4.56       NaN      2.6   20.0
# 1              NaN     0.97   5.89      5.10       NaN      3.1   22.0
# 2              NaN     1.20   6.10      5.43       NaN      4.3   24.0
# 3              NaN     1.67   6.50      5.89       NaN      6.7   26.0
# 4              NaN     2.03   6.40      6.09       NaN      8.1   31.0
#
#             Price Ratios                             \
#                    Price
#   Microsoft      Company Facebook  Google Microsoft
# 0     18.70          NaN    155.0   955.0      66.0
# 1     21.30          NaN    150.0   987.0      69.0
# 2     21.45          NaN    153.0   963.0      62.0
# 3     21.88          NaN    155.0  1000.0      61.0
# 4     22.34          NaN    156.0  1012.0      66.0
#
# ...

# %% [markdown]
# # crosstab() function

# %%
data=pd.read_excel("datasets/survey.xls")
data
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
#applying crosstab() function
pd.crosstab(data.Sex,data.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
pd.crosstab([data.Nationality,data.Sex],[data.Handedness])
# Out:
# Handedness          Left  Right
# Nationality Sex
# Bangadesh   Female     1      0
#             Male       1      0
# China       Female     1      1
#             Male       1      0
# India       Male       2      1
# USA         Female     0      2
#             Male       1      1

# %%
#getting sum or total for all columns and rows
pd.crosstab(data.Sex,data.Handedness,margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
#getting values in terms of percentage
pd.crosstab(data.Sex,data.Handedness,normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %%
#getting the average ages 
import numpy as np
pd.crosstab(data.Sex,data.Handedness,values=data.Age,aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# # Memory management

# %% [markdown]
# Link : https://pythonspeed.com/articles/pandas-load-less-data/

# %%
import pandas as pd

# %% [markdown]
# # Time series Analysis

# %% [markdown]
# DateTimeIndex and resample

# %%
data=pd.read_csv("D:\programming languages\datasets/apple.csv")
#data=pd.read_csv(r"D:\programming languages\datasets\apple.csv")-->can also be used
data
# Out:
#           Date    Open    High     Low   Close    Volume
# 0     7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1     6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2     5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3     3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4    30-Jun-17  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246  15-Jul-16   98.92   99.30   98.50   98.78  30136990
# 247  14-Jul-16   97.39   98.99   97.32   98.79  38918997
# 248  13-Jul-16   97.41   97.67   96.84   96.87  25892171
# 249  12-Jul-16   97.17   97.70   97.12   97.42  24167463
# 250  11-Jul-16   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
#converting datatype of Date from string to timestamp
data['Date']=pd.to_datetime(data.Date)
data
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
data.set_index('Date',inplace=True)
data
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
#'Date' can be directly set as index while importing the csv file
#data=pd.read_csv("D:\programming languages\datasets/apple.csv",parse_dates=['Date'],index_col='Date')

# %%
#extracting details of a particular date
data['2017-06-15']
# Out:
# <ipython-input-139-7e82f932ccde>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data['2017-06-15']
#               Open    High     Low   Close    Volume
# Date
# 2017-06-15  143.32  144.48  142.21  144.29  32165373

# %%
#Extracting data of a particular month
data['2017-06']#extracting the data in the month of June
# Out:
# <ipython-input-140-4d91b1fdbdad>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data['2017-06']#extracting the data in the month of June
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# ...

# %%
#extracting particular range of dates
data['2017-06-15':'2017-06-01']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-01  153.17  153.33  152.22  153.18  16404088

# %%
#getting average stock price in the month of june
data['2017-06'].Close.mean()
# Out:
# <ipython-input-142-c1e95bd654ce>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data['2017-06'].Close.mean()
# 147.8313636363636

# %%
#plottig graph for the closing price in June
# %matplotlib inline
data['2017-06'].Close.plot()
# Out:
# <ipython-input-143-9ec157135882>:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data['2017-06'].Close.plot()
# <AxesSubplot:xlabel='Date'>

# %%
#getting monthly average of closing price
data.Close.resample('M').mean()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
#plotting the graph for mothly average of closing price 
# %matplotlib inline
data.Close.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plotting the graph for weekly average of closing price 
# %matplotlib inline
data.Close.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plotting barplot the graph for mothly average of closing price 
# %matplotlib inline
data.Close.resample('M').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # date_range() function

# %%
#generating dates between given range
dates=pd.date_range(start='10/27/2002',end="11/27/2002")
#dates=pd.date_range('10/27/2002',"11/27/2002")-->simply this also applicable
dates
# Out:
# DatetimeIndex(['2002-10-27', '2002-10-28', '2002-10-29', '2002-10-30',
#                '2002-10-31', '2002-11-01', '2002-11-02', '2002-11-03',
#                '2002-11-04', '2002-11-05', '2002-11-06', '2002-11-07',
#                '2002-11-08', '2002-11-09', '2002-11-10', '2002-11-11',
#                '2002-11-12', '2002-11-13', '2002-11-14', '2002-11-15',
#                '2002-11-16', '2002-11-17', '2002-11-18', '2002-11-19',
#                '2002-11-20', '2002-11-21', '2002-11-22', '2002-11-23',
#                '2002-11-24', '2002-11-25', '2002-11-26', '2002-11-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
#generating dates by giving only startig date and no.days in periods parameter
dates=pd.date_range(start='10/27/2002',periods=30)
dates
# Out:
# DatetimeIndex(['2002-10-27', '2002-10-28', '2002-10-29', '2002-10-30',
#                '2002-10-31', '2002-11-01', '2002-11-02', '2002-11-03',
#                '2002-11-04', '2002-11-05', '2002-11-06', '2002-11-07',
#                '2002-11-08', '2002-11-09', '2002-11-10', '2002-11-11',
#                '2002-11-12', '2002-11-13', '2002-11-14', '2002-11-15',
#                '2002-11-16', '2002-11-17', '2002-11-18', '2002-11-19',
#                '2002-11-20', '2002-11-21', '2002-11-22', '2002-11-23',
#                '2002-11-24', '2002-11-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
#generating dates by giving only startig date and no.days in periods parameter excluding weekends
dates=pd.date_range(start='10/27/2002',periods=30,freq='B')#B-->business day exluding weekends
dates
# Out:
# DatetimeIndex(['2002-10-28', '2002-10-29', '2002-10-30', '2002-10-31',
#                '2002-11-01', '2002-11-04', '2002-11-05', '2002-11-06',
#                '2002-11-07', '2002-11-08', '2002-11-11', '2002-11-12',
#                '2002-11-13', '2002-11-14', '2002-11-15', '2002-11-18',
#                '2002-11-19', '2002-11-20', '2002-11-21', '2002-11-22',
#                '2002-11-25', '2002-11-26', '2002-11-27', '2002-11-28',
#                '2002-11-29', '2002-12-02', '2002-12-03', '2002-12-04',
#                '2002-12-05', '2002-12-06'],
#               dtype='datetime64[ns]', freq='B')

# %%
#creating sample series data
import numpy as np
temp=np.random.randint(1,30,len(dates))
temp
# Out:
# array([ 8,  5, 27, 15, 13, 20,  8,  9, 19, 26, 20, 21, 18, 19, 16, 29,  6,
#        27,  5, 25, 19, 21, 22, 28,  3, 22, 20, 15, 28, 20])

# %%
pd.Series(temp,index=dates)
# Out:
# 2002-10-28     8
# 2002-10-29     5
# 2002-10-30    27
# 2002-10-31    15
# 2002-11-01    13
# 2002-11-04    20
# 2002-11-05     8
# 2002-11-06     9
# 2002-11-07    19
# 2002-11-08    26
# 2002-11-11    20
# 2002-11-12    21
# 2002-11-13    18
# 2002-11-14    19
# 2002-11-15    16
# 2002-11-18    29
# 2002-11-19     6
# 2002-11-20    27
# 2002-11-21     5
# 2002-11-22    25
# 2002-11-25    19
# 2002-11-26    21
# 2002-11-27    22
# 2002-11-28    28
# 2002-11-29     3
# 2002-12-02    22
# 2002-12-03    20
# 2002-12-04    15
# 2002-12-05    28
# 2002-12-06    20
# Freq: B, dtype: int32

# %%
dates=pd.date_range('10/10/2020','30/10/2020',freq='B')
dates
# Out:
# DatetimeIndex(['2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                '2020-10-16', '2020-10-19', '2020-10-20', '2020-10-21',
#                '2020-10-22', '2020-10-23', '2020-10-26', '2020-10-27',
#                '2020-10-28', '2020-10-29', '2020-10-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.offsets import CustomBusinessDay

# %%
#Declaring october 27 as holiday
bd=CustomBusinessDay(weekmask='Mon Tue Wed Thu Fri',holidays=["2020-10-27"])

# %%
dates=pd.date_range('10/10/2020','30/10/2020',freq=bd)
dates
# Out:
# DatetimeIndex(['2020-10-12', '2020-10-13', '2020-10-14', '2020-10-15',
#                '2020-10-16', '2020-10-19', '2020-10-20', '2020-10-21',
#                '2020-10-22', '2020-10-23', '2020-10-26', '2020-10-28',
#                '2020-10-29', '2020-10-30'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# # to_datetime() function

# %%
#converting different formats of date to yyyy-mm-dd format
dates = ['2017-01-05', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-05', '2017-01-05', '2017-01-05',
#                '2017-01-05', '2017-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
#converting time along with dates
#dates = ['2017-01-05 2:30:00 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
#dates = ['2017-01-05 02:30 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
#dates = ['2017-01-05 2:30', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
#above are also possible
dates = ['2017-01-05 02:30:00 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
#by default it can consider only mm-dd-yy format but not dd-mm-yy
date='07/10/2002'#october 07
pd.to_datetime(date)
#result : july 10
# Out:
# Timestamp('2002-07-10 00:00:00')

# %%
pd.to_datetime(date,dayfirst=True)#it is october 07
# Out:
# Timestamp('2002-10-07 00:00:00')

# %%
#giving input interms of dd$mm$$yyyy
date='27$10$2002'
pd.to_datetime(date,format='%d$%m$%Y')
# Out:
# Timestamp('2002-10-27 00:00:00')

# %%
#handling unknown string
dates = ['2017-01-05 02:30:00 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105','sharath']
pd.to_datetime(dates)
#throws an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-160-e79672d730d2> in <module>
#       1 #handling unknown string
# ...

# %%
dates = ['2017-01-05 02:30:00 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105','sharath']
pd.to_datetime(dates,errors='ignore')#errors="coerce" => converts sharath to naT(not a time)
# Out:
# Index(['2017-01-05 02:30:00 pm', 'Jan 5, 2017', '01/05/2017', '2017.01.05',
#        '2017/01/05', '20170105', 'sharath'],
#       dtype='object')

# %% [markdown]
# # shift() function

# %%
import pandas as pd
lst=[
("15-Aug-17",171),
("16-Aug-17",170),
("17-Aug-17",166.91),
("18-Aug-17",167.41),
("21-Aug-17",167.78),
("22-Aug-17",169.64),
("23-Aug-17",168.71),
("24-Aug-17",167.74),
("25-Aug-17",166.32),
("28-Aug-17",167.24)
]
data=pd.DataFrame(lst,columns=["Date","Price"])
data
# Out:
#         Date   Price
# 0  15-Aug-17  171.00
# 1  16-Aug-17  170.00
# 2  17-Aug-17  166.91
# 3  18-Aug-17  167.41
# 4  21-Aug-17  167.78
# 5  22-Aug-17  169.64
# 6  23-Aug-17  168.71
# 7  24-Aug-17  167.74
# 8  25-Aug-17  166.32
# 9  28-Aug-17  167.24

# %%
data.Date=pd.to_datetime(data.Date)
data=data.set_index('Date')
data
# Out:
#              Price
# Date
# 2017-08-15  171.00
# 2017-08-16  170.00
# 2017-08-17  166.91
# 2017-08-18  167.41
# 2017-08-21  167.78
# 2017-08-22  169.64
# 2017-08-23  168.71
# 2017-08-24  167.74
# 2017-08-25  166.32
# 2017-08-28  167.24

# %%
#shifting prices to next day i.e. price of aug 15 is shifted to aug 16
data.shift(1)
# Out:
#              Price
# Date
# 2017-08-15     NaN
# 2017-08-16  171.00
# 2017-08-17  170.00
# 2017-08-18  166.91
# 2017-08-21  167.41
# 2017-08-22  167.78
# 2017-08-23  169.64
# 2017-08-24  168.71
# 2017-08-25  167.74
# 2017-08-28  166.32

# %%
#shifting prices to 2 days i.e. price of aug 15 is shifted to aug 17
data.shift(2)
# Out:
#              Price
# Date
# 2017-08-15     NaN
# 2017-08-16     NaN
# 2017-08-17  171.00
# 2017-08-18  170.00
# 2017-08-21  166.91
# 2017-08-22  167.41
# 2017-08-23  167.78
# 2017-08-24  169.64
# 2017-08-25  168.71
# 2017-08-28  167.74

# %%
##shifting prices to previous day i.e. price of aug 16 is shifted to aug 15
data.shift(-1)
# Out:
#              Price
# Date
# 2017-08-15  170.00
# 2017-08-16  166.91
# 2017-08-17  167.41
# 2017-08-18  167.78
# 2017-08-21  169.64
# 2017-08-22  168.71
# 2017-08-23  167.74
# 2017-08-24  166.32
# 2017-08-25  167.24
# 2017-08-28     NaN

# %%
#creating a column having previous day prices
data['previous day price']=data.shift(1)
data
# Out:
#              Price  previous day price
# Date
# 2017-08-15  171.00                 NaN
# 2017-08-16  170.00              171.00
# 2017-08-17  166.91              170.00
# 2017-08-18  167.41              166.91
# 2017-08-21  167.78              167.41
# 2017-08-22  169.64              167.78
# 2017-08-23  168.71              169.64
# 2017-08-24  167.74              168.71
# 2017-08-25  166.32              167.74
# 2017-08-28  167.24              166.32

# %%
#fetching the price change
data['price change']=data['Price']-data['previous day price']
data
# Out:
#              Price  previous day price  price change
# Date
# 2017-08-15  171.00                 NaN           NaN
# 2017-08-16  170.00              171.00         -1.00
# 2017-08-17  166.91              170.00         -3.09
# 2017-08-18  167.41              166.91          0.50
# 2017-08-21  167.78              167.41          0.37
# 2017-08-22  169.64              167.78          1.86
# 2017-08-23  168.71              169.64         -0.93
# 2017-08-24  167.74              168.71         -0.97
# 2017-08-25  166.32              167.74         -1.42
# 2017-08-28  167.24              166.32          0.92

# %%
data['5 day % return']=(data['Price']-data['Price'].shift(-5))*100/data['Price'].shift(-5)
data
# Out:
#              Price  previous day price  price change  5 day % return
# Date
# 2017-08-15  171.00                 NaN           NaN        0.801698
# 2017-08-16  170.00              171.00         -1.00        0.764626
# 2017-08-17  166.91              170.00         -3.09       -0.494813
# 2017-08-18  167.41              166.91          0.50        0.655363
# 2017-08-21  167.78              167.41          0.37        0.322889
# 2017-08-22  169.64              167.78          1.86             NaN
# 2017-08-23  168.71              169.64         -0.93             NaN
# 2017-08-24  167.74              168.71         -0.97             NaN
# 2017-08-25  166.32              167.74         -1.42             NaN
# 2017-08-28  167.24              166.32          0.92             NaN

# %% [markdown]
# # tshift() function
# moving the dates

# %%
data=data['Price']
data
# Out:
# Date
# 2017-08-15    171.00
# 2017-08-16    170.00
# 2017-08-17    166.91
# 2017-08-18    167.41
# 2017-08-21    167.78
# 2017-08-22    169.64
# 2017-08-23    168.71
# 2017-08-24    167.74
# 2017-08-25    166.32
# 2017-08-28    167.24
# Name: Price, dtype: float64

# %%
data.index
#here freq=None so converting it into freq='B'
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
data.index=pd.date_range(start="2017-08-15",end="2017-08-28",freq="B")
data.index
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
#shifting date to 1 day next
data.tshift(1)
# Out:
# <ipython-input-176-9970806c07e8>:2: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   data.tshift(1)
# 2017-08-16    171.00
# 2017-08-17    170.00
# 2017-08-18    166.91
# 2017-08-21    167.41
# 2017-08-22    167.78
# 2017-08-23    169.64
# 2017-08-24    168.71
# 2017-08-25    167.74
# 2017-08-28    166.32
# 2017-08-29    167.24
# Freq: B, Name: Price, dtype: float64

# %%
#shifting date to one day previous
data.tshift(-1)
# Out:
# <ipython-input-177-6916c8ecb0db>:2: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   data.tshift(-1)
# 2017-08-14    171.00
# 2017-08-15    170.00
# 2017-08-16    166.91
# 2017-08-17    167.41
# 2017-08-18    167.78
# 2017-08-21    169.64
# 2017-08-22    168.71
# 2017-08-23    167.74
# 2017-08-24    166.32
# 2017-08-25    167.24
# Freq: B, Name: Price, dtype: float64
